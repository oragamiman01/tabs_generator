# %%
# import os
# os.environ["IMAGEIO_FFMPEG_EXE"] = "/usr/bin/ffmpeg"
from moviepy.editor import *

path = "../data/"
filename = "dumb_scale_youtube.mp4"
exp_filename = "dumb_scale_youtube.wav"

video = VideoFileClip(path + filename)
fps = video.fps
video.write_images_sequence(path + "frame%03d.jpeg")
# audio = video.audio
# audio.write_audiofile(path + exp_filename)
# Out:
# Moviepy - Writing frames ../data/frame%03d.jpeg.
# Moviepy - Done writing frames ../data/frame%03d.jpeg.
# ['../data/frame000.jpeg',
#  '../data/frame001.jpeg',
#  '../data/frame002.jpeg',
#  '../data/frame003.jpeg',
#  '../data/frame004.jpeg',
#  '../data/frame005.jpeg',
#  '../data/frame006.jpeg',
#  '../data/frame007.jpeg',
#  '../data/frame008.jpeg',
#  '../data/frame009.jpeg',
#  '../data/frame010.jpeg',
#  '../data/frame011.jpeg',
#  '../data/frame012.jpeg',
#  '../data/frame013.jpeg',
#  '../data/frame014.jpeg',
#  '../data/frame015.jpeg',
#  '../data/frame016.jpeg',
#  '../data/frame017.jpeg',
#  '../data/frame018.jpeg',
#  '../data/frame019.jpeg',
#  '../data/frame020.jpeg',
#  '../data/frame021.jpeg',
#  '../data/frame022.jpeg',
#  '../data/frame023.jpeg',
#  '../data/frame024.jpeg',
#  '../data/frame025.jpeg',
#  '../data/frame026.jpeg',
#  '../data/frame027.jpeg',
#  '../data/frame028.jpeg',
#  '../data/frame029.jpeg',
#  '../data/frame030.jpeg',
#  '../data/frame031.jpeg',
#  '../data/frame032.jpeg',
#  '../data/frame033.jpeg',
#  '../data/frame034.jpeg',
#  '../data/frame035.jpeg',
#  '../data/frame036.jpeg',
#  '../data/frame037.jpeg',
#  '../data/frame038.jpeg',
#  '../data/frame039.jpeg',
#  '../data/frame040.jpeg',
#  '../data/frame041.jpeg',
#  '../data/frame042.jpeg',
#  '../data/frame043.jpeg',
#  '../data/frame044.jpeg',
#  '../data/frame045.jpeg',
#  '../data/frame046.jpeg',
#  '../data/frame047.jpeg',
#  '../data/frame048.jpeg',
#  '../data/frame049.jpeg',
#  '../data/frame050.jpeg',
#  '../data/frame051.jpeg',
#  '../data/frame052.jpeg',
#  '../data/frame053.jpeg',
#  '../data/frame054.jpeg',
#  '../data/frame055.jpeg',
#  '../data/frame056.jpeg',
#  '../data/frame057.jpeg',
#  '../data/frame058.jpeg',
#  '../data/frame059.jpeg',
#  '../data/frame060.jpeg',
#  '../data/frame061.jpeg',
#  '../data/frame062.jpeg',
#  '../data/frame063.jpeg',
#  '../data/frame064.jpeg',
#  '../data/frame065.jpeg',
#  '../data/frame066.jpeg',
#  '../data/frame067.jpeg',
#  '../data/frame068.jpeg',
#  '../data/frame069.jpeg',
#  '../data/frame070.jpeg',
#  '../data/frame071.jpeg',
#  '../data/frame072.jpeg',
#  '../data/frame073.jpeg',
#  '../data/frame074.jpeg',
#  '../data/frame075.jpeg',
#  '../data/frame076.jpeg',
#  '../data/frame077.jpeg',
#  '../data/frame078.jpeg',
#  '../data/frame079.jpeg',
#  '../data/frame080.jpeg',
#  '../data/frame081.jpeg',
#  '../data/frame082.jpeg',
#  '../data/frame083.jpeg',
#  '../data/frame084.jpeg',
#  '../data/frame085.jpeg',
#  '../data/frame086.jpeg',
#  '../data/frame087.jpeg',
#  '../data/frame088.jpeg',
#  '../data/frame089.jpeg',
#  '../data/frame090.jpeg',
#  '../data/frame091.jpeg',
#  '../data/frame092.jpeg',
#  '../data/frame093.jpeg',
#  '../data/frame094.jpeg',
#  '../data/frame095.jpeg',
#  '../data/frame096.jpeg',
#  '../data/frame097.jpeg',
#  '../data/frame098.jpeg',
#  '../data/frame099.jpeg',
#  '../data/frame100.jpeg',
#  '../data/frame101.jpeg',
#  '../data/frame102.jpeg',
#  '../data/frame103.jpeg',
#  '../data/frame104.jpeg',
#  '../data/frame105.jpeg',
#  '../data/frame106.jpeg',
#  '../data/frame107.jpeg',
#  '../data/frame108.jpeg',
#  '../data/frame109.jpeg',
#  '../data/frame110.jpeg',
#  '../data/frame111.jpeg',
#  '../data/frame112.jpeg',
#  '../data/frame113.jpeg',
#  '../data/frame114.jpeg',
#  '../data/frame115.jpeg',
#  '../data/frame116.jpeg',
#  '../data/frame117.jpeg',
#  '../data/frame118.jpeg',
#  '../data/frame119.jpeg',
#  '../data/frame120.jpeg',
#  '../data/frame121.jpeg',
#  '../data/frame122.jpeg',
#  '../data/frame123.jpeg',
#  '../data/frame124.jpeg',
#  '../data/frame125.jpeg',
#  '../data/frame126.jpeg',
#  '../data/frame127.jpeg',
#  '../data/frame128.jpeg',
#  '../data/frame129.jpeg',
#  '../data/frame130.jpeg',
#  '../data/frame131.jpeg',
#  '../data/frame132.jpeg']
