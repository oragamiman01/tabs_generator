# %%
# import os
# os.environ["IMAGEIO_FFMPEG_EXE"] = "/usr/bin/ffmpeg"
from moviepy.editor import *

path = "../data/"
filename = "dumb_scale_youtube.mp4"

video = VideoFileClip(path + filename)
fps = video.fps
# names = video.write_images_sequence(path + "frame%03d.jpeg")
audio = video.audio
audio_list = [n[0] for n in audio.iter_frames()]
# audio.write_audiofile(path + exp_filename)
# Out:
# [0.003082275390625, 0.005706787109375, 0.010955810546875, 0.017547607421875, 0.02435302734375, 0.0313720703125, 0.037445068359375, 0.0416259765625, 0.044342041015625, 0.045928955078125, 0.046417236328125, 0.046630859375, 0.04742431640625, 0.04937744140625, 0.052734375, 0.057098388671875, 0.0621337890625, 0.0673828125, 0.071624755859375, 0.07415771484375, 0.075531005859375, 0.07562255859375, 0.074310302734375, 0.072265625, 0.0697021484375, 0.066314697265625, 0.062347412109375, 0.0574951171875, 0.051483154296875, 0.04449462890625, 0.036468505859375, 0.027618408203125, 0.01898193359375, 0.011322021484375, 0.004974365234375, 0.000213623046875, -0.002960205078125, -0.00457763671875, -0.0048828125, -0.00482177734375, -0.00506591796875, -0.005828857421875, -0.007415771484375, -0.00946044921875, -0.0111083984375, -0.01226806640625, -0.012420654296875, -0.010650634765625, -0.007080078125, -0.002044677734375, 0.004241943359375, 0.01092529296875, 0.01727294921875, 0.0230712890625, 0.02807617187
# ...
